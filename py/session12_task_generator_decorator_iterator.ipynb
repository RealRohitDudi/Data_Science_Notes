# %% [markdown]
# <a href="https://colab.research.google.com/github/RealRohitDudi/Data_Science_Notes/blob/main/session12_task_generator_decorator_iterator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Namespace and Scope

# %% [markdown]
# ###`Q1:` Write `Person` Class as given below and then display it's namespace.

# %% [markdown]
# ```
# Class Name - Person
#
# Attributes:
# name - public
# state - public
# city - private
# age - private
#
# Methods:
# address - public
# It give address of the person as "<name>, <city>, <state>"
# ```

# %%
#Write your code here
class Person:
  def __init__(self,name,state,city,age):
   self.name = name
   self.state = state
   self.__city = city
   self.__age = age
  def address(self):
    return f"{self.name}, {self.__city}, {self.state}"

obj = Person('rohit','rajasthan','jaipur',20)

print(obj.address())
# Out:
# rohit, jaipur, rajaathan

# %% [markdown]
# ###`Q2:` Write a program to show namespace of object/instance of above(Person) class.

# %%
# Write your code here
class Person:
  def __init__(self,name,state,city,age):
   self.name = name
   self.state = state
   self.__city = city
   self.__age = age
  def address(self):
    return f"{self.name}, {self.__city}, {self.state}"

obj = Person('rohit','rajasthan','jaipur',20)

print(obj._Person__city)

print("\nClass namespace attributes are: ")
print(Person.__dict__)
print("\nObject namespace attributes are: ")
print(obj.__dict__)
# Out:
# jaipur
#
# Class namespace attributes are:
# {'__module__': '__main__', '__init__': <function Person.__init__ at 0x7d1c505e1120>, 'address': <function Person.address at 0x7d1c505e02c0>, '__dict__': <attribute '__dict__' of 'Person' objects>, '__weakref__': <attribute '__weakref__' of 'Person' objects>, '__doc__': None}
#
# Object namespace attributes are:
# {'name': 'rohit', 'state': 'rajasthan', '_Person__city': 'jaipur', '_Person__age': 20}

# %% [markdown]
# ###`Q3:` Write a recursive program to to calculate `gcd` and print no. of function calls taken to find the solution.
# ```
# gcd(5,10) -> result in 5 as gcd and function call 4
# ```

# %%
#Write your code here

def gcd(a,b):
  if(b==0):
    return a
  else:
    return gcd(b,a%b)

print(gcd(5,10))
# Out:
# 5

# %% [markdown]
# ## Itterator And Generator

# %% [markdown]
# ###`Q4:` Create MyEnumerate class,
# Create your own `MyEnumerate` class such that someone can use it instead of enumerate. It will need to return a `tuple` with each iteration, with the first element in the tuple being the `index` (starting with 0) and the second element being the `current element` from the underlying data structure. Trying to use `MyEnumerate` with a noniterable argument will result in an error.
#
# ```
# for index, letter in MyEnumerate('abc'):
#     print(f'{index} : {letter}')
# ```
#
# Output:
# ```
# 0 : a
# 1 : b
# 2 : c
# ```

# %%
#Write your code here
class MyEnumerate:
  def __init__(self,data):
    try:
      iter(data) # Attempt to get an iterator
    except TypeError:
      raise TypeError(f"'{type(data).__name__}' object is not iterable")
    self.data = data

  def __iter__(self):
    self.current_index = 0
    while self.current_index < len(self.data):
       yield (self.current_index, self.data[self.current_index])
       self.current_index += 1

for index, letter in MyEnumerate('abc'):
    print(f'{index} : {letter}')

fruits = ['apple','berry','grapes','dates','orange']
enum_fruits = MyEnumerate(fruits)
for index, value in enum_fruits:
  print(f"{index} : {value}")
# Out:
# 0 : a
# 1 : b
# 2 : c
# 0 : apple
# 1 : berry
# 2 : grapes
# 3 : dates
# 4 : orange

# %% [markdown]
# ###`Q5:` Iterate in circle
# Define a class, `Circle`, that takes two arguments when defined: a sequence and a number. The idea is that the object will then return elements the defined number of times. If the number is greater than the number of elements, then the sequence  repeats as necessary. You can define an another class used as a helper (like I call `CircleIterator`).
#
# ```
# c = Circle('abc', 5)
# d = Circle('abc', 7)
# print(list(c))
# print(list(d))
# ```
#
# Output
# ```
# [a, b, c, a, b]
# [a, b, c, a, b, c, a]
# ```

# %%
class CircleIterator:
  def __init__(self, sequence, number):
    self._sequence = sequence
    self._number = number
    self._current_count = 0
    self._index = 0

  def __iter__(self):
    return self

  def __next__(self):
    if self._current_count < self._number:
      item = self._sequence[self._index]
      self._index = (self._index + 1) % len(self._sequence) #?
      self._current_count += 1
      return item
    else:
      raise StopIteration

class Circle:
  def __init__(self, sequence, number):
    self.sequence = sequence
    self.number = number

  def __iter__(self):
    return CircleIterator(self.sequence, self.number)

# %%
c = Circle('abc', 5)
d = Circle('abc', 7)
print(list(c))
print(list(d))
# Out:
# ['a', 'b', 'c', 'a', 'b']
# ['a', 'b', 'c', 'a', 'b', 'c', 'a']

# %%
# Out:
# ['a', 'b', 'c', 'a', 'b']

# %% [markdown]
# ###`Q6:` Generator time elapsed
# Write a generator function whose argument must be iterable. With each iteration, the generator will return a two-element tuple. The first element in the tuple will be an integer indicating how many seconds have passed since the previous iteration. The tuple’s second element will be the next item from the passed argument.
#
# Note that the timing should be relative to the previous iteration, not when the
# generator was first created or invoked. Thus the timing number in the first iteration
# will be 0
#
# ```
# for t in elapsed_since('abcd'):
#     print(t)
#     time.sleep(2)
# ```
#
# Output:
# ```
# (0.0, 'a')
# (2.005651817999933, 'b')
# (2.0023095009998997, 'c')
# (2.001949742000079, 'd')
# ```
# Note: Your output may differ because of diffrent system has different processing configuration.

# %%
#Write yor code
import time
def elapsed_since(value):
  start_time = time.time()
  for item in value:
    current_time = time.time()
    elapsed_time = current_time - start_time
    yield (elapsed_time, item)

for t in elapsed_since('abcd'):
    print(t)
    time.sleep(2)
# Out:
# (9.5367431640625e-07, 'a')
# (2.0001673698425293, 'b')
# (4.0003743171691895, 'c')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_739/3226946264.py in <cell line: 0>()
#      10 for t in elapsed_since('abcd'):
#      11     print(t)
# ---> 12     time.sleep(2)
#
# KeyboardInterrupt:

# %%
# Out:
# (0.0, 'a')
# (2.005651817999933, 'b')
# (2.0023095009998997, 'c')
# (2.001949742000079, 'd')

# %% [markdown]
# ## Decorators

# %% [markdown]
# ###`Q7:` Write a Python program to make a chain of function decorators (bold, italic, underline etc.) on a given function which prints "hello world"
#
# ```
# def hello():
#     return "hello world"
# ```
#
# ```
# bold - wrap string with <b> tag. <b>Str</b>
# italic - wrap string with <i> tag. <i>Str</i>
# underline- wrap string with <u> tag. <u>Str</u>
# ```

# %%
#Write your code here

def bold(func):
  def wrapper(str):
    return func('<b>'+str+'</b>')
  return wrapper

def italic(func):
  def wrapper(str):
    return func('<i>'+str+'</i>')
  return wrapper

def underline(func):
  def wrapper(str):
    return func('<u>'+str+'</u>')
  return wrapper

def hello(str):
  print(str)

@bold
@italic
@underline
def hello(str):
  print(str)
hello("Good morning")
# Out:
# <u><i><b>Good morning</b></i></u>

# %%
# Out:
# <b><i><u>hello world</u></i></b>

# %% [markdown]
# ###`Q8:` Write a decorator called `printer` which causes any decorated function to print their return values. If the return value of a given function is `None`, printer should do nothing.

# %%
#Write your code here
import datetime
def printer(func):
  def wrapper(str):
    result = func(str)
    if result is not None:
      print(result)
  return wrapper

@printer
def greeting(name):
  current_hour = datetime.datetime.now().hour
  if  current_hour < 12:
    return "Good morning " + name
  elif current_hour < 18:
    return "Good afternoon " + name
  elif current_hour < 20:
    return "Good Evening " + name
  else:
    return "Good Night " + name

greeting("Rohit")
# Out:
# Good morning Rohit

# %%
# Out:
# abc
# pqr

# %% [markdown]
# ###`Q9:` Make a decorator which calls a given function twice. You can assume the functions don't return anything important, but they may take arguments.
# ```
# #Lets say given function
# def hello(string):
#     print(string)
#
# #on calling after specified decorator is inplaced
# hello('hello')
# ```
#
# Output:
# ```
# hello
# hello
# ```

# %%
#Write your cod here
def call_twice(func):
  def wrapper(inp):
    func(inp)
    func(inp)
  return wrapper

@call_twice
def hello(name):
  print("hello")

hello("Rohit")
# Out:
# hello
# hello

# %%
# Out:
# hello
# hello

# %% [markdown]
# ### `Q10:` Write a decorator which doubles the return value of any function. And test that decoratos is working correctly or not using `asert`.
#
# ```
# add(2,3) -> result in 10. Without decorator it should be 5.
# ```

# %%
# Write your code here
def double_the_value(func):
  def wrapper(inp):
    result = func(inp)
    print("Original value: ", result)
    print("double value: ", result * 2)
  return wrapper

@double_the_value
def square(value):
  return value * value

square(2)
# Out:
# Original value:  4
# double value:  8
