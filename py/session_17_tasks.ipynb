# %% [markdown]
# <a href="https://colab.research.google.com/github/RealRohitDudi/Data_Science_Notes/blob/main/session_17_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %% [markdown]
# ## Basic DataFrame
#
# Consider the following Python dictionary data and Python list labels:
#
# ```
# data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills', 'Cranes'],
#         'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4, 3.5], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2, 2],
#         'priority': ['yes', 'yes', 'no', np.nan, 'no', 'no', 'no', 'yes', 'no', 'no','yes']}
# ```
# ```
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']
# ```

# %% [markdown]
# ###`Q-1:`
# i. Create a DataFrame birds from the above dictionary data which has the index labels.
#
# ii. Display basic information about the dataFrame.
#
# iii. Show Alternate rows of the dataframe.

# %%
# code here
import numpy as np
import pandas as pd
data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills', 'Cranes'],
        'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4, 3.5], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2, 2],
        'priority': ['yes', 'yes', 'no', np.nan, 'no', 'no', 'no', 'yes', 'no', 'no','yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']
birds_data = pd.DataFrame(data)
birds_data.index = labels
birds_data.info()
birds_data.iloc[::2]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, a to k
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   birds     11 non-null     object
#  1   age       9 non-null      float64
#  2   visits    11 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 440.0+ bytes
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# i  spoonbills  8.0       3       no
# k      Cranes  3.5       2      yes

# %% [markdown]
# ###`Q-2:`
# i. Show only rows [1st, 3rd, 7th] from columns ['bird', 'age']
#
# ii. Select rows where the number of visits is less than 4.

# %%
# code here
birds_data.loc[['a','c','d'],['birds','age']]
# Out:
#         birds  age
# a      Cranes  3.5
# c     plovers  1.5
# d  spoonbills  NaN

# %% [markdown]
# ###`Q-3:`
# i. Select all rows with nan values in age and visits column.
#
# ii. Fill nan with respective series mode value.

# %%
# code here
birds_data['age'].fillna(birds_data['age'].mode()[0],inplace=True)
birds_data['visits'].fillna(birds_data['visits'].mode()[0],inplace=True)
print(birds_data)
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  3.5       4      NaN
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  3.5       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
# k      Cranes  3.5       2      yes
# /tmp/ipykernel_9323/1112106821.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ###`Q-4`
# i. Find the total number of visits of the bird Cranes
#
# ii. Find the number of each type of birds in dataframe.
#
# iii. Print no of duplicate rows
#
# iv. Drop Duplicates rows and make this changes permanent. Show dataframe after changes.

# %%
# code here
print("total vivits: ",birds_data['visits'].sum())
print("no of each type of birds",birds_data['birds'].value_counts())
print("duplicated",birds_data.duplicated().sum())
birds_data.drop_duplicates(inplace=True)
print(birds_data)
# Out:
# total vivits:  29
# no of each type of birds birds
# Cranes        4
# spoonbills    4
# plovers       2
# Name: count, dtype: int64
# duplicated 0
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      NaN
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %% [markdown]
# ##Question on IPL Data
#
# IPL Data Link :  https://drive.google.com/file/d/1yKVUuexl6lIKuFQy7uIPgDgXhJ0L4SIg/view?usp=share_link
#
# https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv
#
# Download ipl matches 2008-2022 file.

# %% [markdown]
# ###`Q-5:` In IPL matches dataset some teams name has changed.
# You will have to consider them as same.
# ```
# 'Delhi Capitals' formerly as 'Delhi Daredevils'
# 'Punjab Kings' formerly as 'Kings XI Punjab'
# 'Rising Pune Supergiant' formerly as 'Rising Pune Supergiants'
# ```
# You need to make changes accordingly. Consider current name for each teams.
#
# Be careful Gujrat Titans and Gujrat Lions are different teams.

# %%
# code here
ipl_data = pd.read_csv("/content/ipl_data.csv")

ipl_data.loc[ipl_data["Team1"] == "Delhi Capitals","Team1"] = "Delhi Daredevils"
ipl_data.loc[ipl_data["Team2"] == "Delhi Capitals","Team2"] = "Delhi Daredevils"

ipl_data.loc[ipl_data["Team1"] == "Punjab Kings","Team1"] = "Kings XI Punjab"
ipl_data.loc[ipl_data["Team2"] == "Punjab Kings","Team2"] = "Kings XI Punjab"

ipl_data.loc[ipl_data["Team1"] == "Rising Pune Supergiant","Team1"] = "Rising Pune Supergiants"
ipl_data.loc[ipl_data["Team2"] == "Rising Pune Supergiant","Team2"] = "Rising Pune Supergiants"


print(ipl_data.sample())
# Out:
#          ID       City        Date Season MatchNumber  \
# 616  598008  Bangalore  2013-04-11   2013          12
#
#                            Team1                  Team2  \
# 616  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                      Venue                   TossWinner TossDecision  \
# 616  M Chinnaswamy Stadium  Royal Challengers Bangalore        field
#
#     SuperOver                  WinningTeam    WonBy  Margin method  \
# 616         N  Royal Challengers Bangalore  Wickets     8.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 616        CH Gayle  ['CH Gayle', 'MA Agarwal', 'V Kohli', 'AB de V...
#
#                                           Team2Players    Umpire1  \
# 616  ['MS Bisla', 'G Gambhir', 'JH Kallis', 'YK Pat...  Asad Rauf
#
#           Umpire2
# 616  AK Chaudhary

# %% [markdown]
# ###`Q-6` Write a code which can display the bar chart of top 5 teams who have played maximum number of matches in the IPL.
# >  Hint: Be careful the data is divided in 2 different cols(Team 1 and Team 2)

# %%
# code here
team1 = ipl_data["Team1"].value_counts().head(5)
team2 = ipl_data["Team2"].value_counts().head(5)
merged = pd.concat([team1, team2])
s_unique = merged.groupby(level=0).sum()
print("top 5 teams who have played maximum number of matches in the IPL",s_unique.head())
s_unique.plot(kind="bar")
# Out:
# top 5 teams who have played maximum number of matches in the IPL Chennai Super Kings      111
# Delhi Daredevils         224
# Kings XI Punjab          218
# Kolkata Knight Riders    118
# Mumbai Indians           231
# Name: count, dtype: int64
# <Axes: >

# %% [markdown]
# ###`Q-7:` Player who got Most no. of player of the match award playing against Mumbai Indians.
# > Just for this question assume player of the match award is given to players from winning team. Although this is true in most of the cases.

# %%
# code here
ipl_data = pd.read_csv("/content/ipl_data.csv")
mask1 = ipl_data["Team2" ] == "Mumbai Indians"
new_data = ipl_data[mask1]
new_data["Player_of_Match"].value_counts().head(1)

# ipl_data.loc[ipl_data["WinningTeam"] == "Mumbai Indians"].Player_of_Match.value_counts
# ipl_data.sample()
# Out:
# Player_of_Match
# KA Pollard    8
# Name: count, dtype: int64

# %% [markdown]
# ###`Q-8:` Team1 vs Team2 Dashbord
# Create a function which will take two string(name of two teams) as input. Show win Loss record between them and player getting most player of the match award in matches between these two teams.
# ```
# team1_vs_team2('Kolkata Knight Riders','Chennai Super Kings')
# ```

# %%
ipl_data = pd.read_csv("/content/ipl_data.csv")
ipl_data.sample(5)
# Out:
#           ID        City        Date   Season MatchNumber  \
# 222  1178407  Chandigarh  2019-04-16     2019          32
# 900   336002   Hyderabad  2008-05-25  2007/08          51
# 646   548363     Kolkata  2012-05-12     2012          58
# 71   1304049      Mumbai  2022-03-27     2022           3
# 608   598017   Bangalore  2013-04-16     2013          21
#
#                            Team1                        Team2  \
# 222              Kings XI Punjab             Rajasthan Royals
# 900              Deccan Chargers  Royal Challengers Bangalore
# 646        Kolkata Knight Riders               Mumbai Indians
# 71   Royal Challengers Bangalore                 Punjab Kings
# 608  Royal Challengers Bangalore             Delhi Daredevils
#
#                                             Venue  \
# 222  Punjab Cricket Association IS Bindra Stadium
# 900     Rajiv Gandhi International Stadium, Uppal
# 646                                  Eden Gardens
# ...

# %%
# code here
ipl_data = pd.read_csv("/content/ipl_data.csv")
ipl_data.sample(5)

def compare_teams(team1,team2):
  mask1 = ipl_data["Team1"] == team1
  mask2 = ipl_data["Team2"] == team2
  team1_data = ipl_data[mask1]
  team2_data = ipl_data[mask2]
  WinningTeam1 = team1_data[team1_data["WinningTeam"] == team1]
  WinningTeam2 = team2_data[team2_data["WinningTeam"] == team2]

  # print("winning ",team1_data["WinningTeam"].value_counts())
  print(team1_data["WinningTeam"] == team1)


compare_teams("Rajasthan Royals","Punjab Kings")
# Out:
# 0      False
# 3      False
# 11      True
# 16     False
# 27     False
#        ...
# 917     True
# 920     True
# 926     True
# 931     True
# 944     True
# Name: WinningTeam, Length: 89, dtype: bool

# %% [markdown]
# ### `Q-9:` Find out the top 7 cities where the matches of Kolkata Knight Riders are played frequently and plot the result as bar chart.
#
# *`.plot(kind = "bar")` can help you to plot the bar chart. Also you can learn more about this method from [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)*

# %%
# code here

# %% [markdown]
# ### `Q-10:` Find out the average margin for the team Mumbai Indians for only the session 2011.

# %%
# code here
